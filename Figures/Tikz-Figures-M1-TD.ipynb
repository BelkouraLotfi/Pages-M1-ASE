# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"></ul></div>

# %%
# %load_ext tikzmagic

# %%
# %%tikz --scale .8 --size 600,200 -p amsmath amssymb -f svg --save Vide.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt];
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt];
# \draw[line width=.2pt](0,0) grid (8,3);
#
# %\node[bloc,minimum height=1cm] (G) at (4,1) {Systeme};
# %\draw[fleche] (1,1) -- (G); \draw[fleche] (G) -- (7,1);\draw[fleche] (4,3) -- (G);
# %\draw (1,1) node[above right] {$u(t)$};\draw (4,3) node[right] {$d(t)$};\draw (7,1) node[above left] {$y(t)$};
# %\draw (1.5,.8) node[below, fill=cyan] {commandes};
# %\draw (5,3) node[right, fill=cyan] {perturbations};
# %\draw (6.5,.8) node[below, fill=cyan] {sorties};

# %%
# %%tikz --scale .8  -p amsmath amssymb -f svg --save Pendule.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt]
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (6,8);
# %\foreach \x in {1,2,...,6} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,8} \draw(0,\y)node[below]{\y};
#
# \node (p1) at (2,6) {$\bullet$};%\node[comp,fill=black] (p1) at (2,6) {};
#
# \node[comp,fill=black] (p2) at (4,2) {a};
# \draw[thick] (2,6)--(p2);\draw[dashed] (p1)--(2,1);
# \draw[->, thick] (2,3) arc (-90:-50:2);
#
# \draw[fleche,thick] (2.45,6.15) arc[start angle=15,end angle=330,x radius=5mm, y radius=5mm];
# \node at (4.2,2.7) {$m$};\node at (3,6) {$u(t)$};\node at (2.75,2.5) {$\theta(t)$};

# %%
# %%tikz --scale 1  -p circuitikz,pgfplots -f svg --save moteur-theta.svg
#
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt]
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (8,4);
#
#
# \draw  (1,1) to [open, a] (1,3) % stator voltage
#   to [short, *- ,a] (1,3) % stator current
#   to [R, l=$R$] (3,3) % stator resistance
#   to [L, l=$L$] (5,3) % leakage inductance
#   to [short,  name=M1] (5,1) % magnetizing inductance
#   to [short,-* ,i=$i(t)$] (1,1); % stator voltage
#  \draw (M1) node[elmech,scale=0.9](M2){};
# \draw[fleche] (.6,1) -- (.6,3);\node[left] at (.6,2) {$u(t)$};
# \draw[fleche] (4.5,1.2) -- (4.5,2.8);\node[left] at (4.5,2) {$E(t)$};
#
# \begin{scope}[shift={(7.5,2)}, scale=.4];
# \draw[fill=blue!50](0,0) circle (1 and 2);
# \draw[top color=blue!25,bottom color=black,middle color=blue!50] (-0.5,2) arc (90:270:1 and 2) -- ++(0.5,0) arc (-90:-270:1 and 2) -- cycle;
# \draw[top color=white,bottom color=black!70] (0,3mm) arc (90:270:1.5mm and 3mm)--++(3cm,0) arc (-90:-270:1.5mm and 3mm)-- cycle;
# \draw (3cm,3mm) arc (90:-90:1.5mm and 3mm);
# \end{scope}
# \draw[fleche,thick] (8.65,2.2) arc[start angle=15,end angle=330,x radius=2mm, y radius=6mm];
# \draw[fleche,thick] (6.2,2.75) arc[start angle=85,end angle=230,x radius=3mm, y radius=8mm];
# \draw[fleche,thick] (6.5,1.3) arc[start angle=230,end angle=85,x radius=3mm, y radius=8mm];
# \node at (6,3) {$\Gamma(t)$};
# \node at (6.5,1) {$f\dot\theta(t)$};
# \node at (9,2.5) {$\theta(t)$};
# \draw[dashed,thick] (5,2)--(6.8,2);

# %%
# %%tikz --scale .8  -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save Centrale-therm.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt]
#
# %\draw [gray, very thin] (-1,0) grid [step=1cm] (14,7);
# %\foreach \x in {1,2,...,14} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,7} \draw(0,\y)node[below]{\y};
#
# \node[bloc,minimum height=1cm] (K3) at (3,1) {$\dfrac{b_3}{p+a_3}$};
# \node[bloc,minimum height=1cm] (K1) at (3,4) {$\dfrac{b_1}{p+a_1}$};
# \node[bloc,minimum height=1cm] (K2) at (8.5,4) {$\dfrac{b_2}{p+a_2}$};
# \node[bloc,minimum height=1cm] (K4) at (12,1) {$\dfrac{b_4}{p+a_4}$};
#
# \node[bloc] (c3) at (1,2) {$c_3$};\node[bloc] (c4) at (5,2) {$c_4$};
# \node[bloc] (c5) at (7,2) {$c_5$};\node[bloc] (c6) at (10,2) {$c_6$};
# \node[bloc] (c1) at (6,5) {$c_1$};\node[bloc] (c2) at (11,5) {$c_2$};
#
# \node[comp] (s3) at (5,1) {};\node[comp] (s4) at (7,1) {};\node[comp] (s5) at (10,1) {};
# \node[comp] (s1) at (6,4) {};\node[comp] (s2) at (11,4) {};
#
# \draw[fleche] (0,6) -| (c1);\draw[fleche] (0,6) -| (c2);
# \draw[fleche] (c1) -- (s1);\draw[fleche] (c2) -- (s2);
# \draw[fleche] (0,4) -- (K1);\draw[fleche] (K1) -- (s1);
# \draw[fleche] (s1) -- (K2);\draw[fleche] (K2) -- (s2);\draw[fleche] (s2) -- (14,4);
#
# \draw[fleche] (0,1) -- (K3);\draw[fleche] (K3) -- (s3);
# \draw[fleche] (s3) -- (s4);\draw[fleche] (s4) -- (s5);
# \draw[fleche] (s5) -- (K4);\draw[fleche] (K4) -- (14,1);
#
# \draw[fleche] (0,1) -| (c3);\draw[fleche] (0,6) -| (c5);\draw[fleche] (c5) -- (s4);
# \draw[fleche] (K1) -| (c4);\draw[fleche] (c4) -- (s3);
# \draw[fleche] (K2) -| (c6);\draw[fleche] (c6) -- (s5);
# \draw[thick] (c3) -- (1,3);\draw[fleche] (1,3) -| (s1);
#
# \node[above left] at (2,4) {$r_1$};\node[above left] at (2,1) {$r_3$};
# \node[above left] at (7,4) {$r_2$};\node[above left] at (11,1) {$r_4$};
#
# \node[above right] at (4,4) {$x_1$};\node[above right] at (4,1) {$x_3$};
# \node[above right] at (9.5,4) {$x_2$};\node[above right] at (12.8,1) {$x_4$};
#
# \node[above left] at (0,1) {$u_3$};\node[above left] at (0,4) {$u_2$};\node[above left] at (0,6) {$u_1$};
# \node[above right] at (14,4) {$y_1$};\node[above right] at (14,1) {$y_2$};
#
# \node[below left] at (0,1) {eau};\node[below left] at (0,4) {fuel};\node[below left] at (0,6) {vapeur};
# \node[below right] at (14,4) {pression};\node[below right] at (14,1) {temperature};
#
# \draw[thick,dashed,rounded corners=1pt] (.4,0) rectangle (13.6,6.5);
# %draw,rectangle,thick,

# %%
# %%tikz --scale .8  -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save Rep-Graph1.svg
#
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,very thick,rounded corners=0pt]
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (10,4);
# %\foreach \x in {1,2,...,10} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,4} \draw(0,\y)node[below]{\y};
#
# \node[bloc] (B) at (2,2) {$B$};
# \node[comp] (p1) at (3.5,2) {};\node[comp] (p2) at (8.5,2) {};
# \node[bloc] (I) at (5,2) {$\int$};\node[bloc] (C) at (7,2) {$C$};
# \node[bloc] (D) at (5,3) {$D$};\node[bloc] (A) at (5,1) {$A$};
#
# \draw [fleche](.5, 2) -- (B);
# \draw[fleche] (B) -- (p1);\draw[fleche] (p1) -- (I);\draw[fleche] (I) -- (C);
# \draw[fleche] (C) -- (p2);\draw[fleche] (p2) -- (9.5,2);
# \draw[fleche] (1.1,2) |- (D);\draw[fleche] (D) -| (p2);
# \draw[fleche] (6,2) |- (A);\draw[fleche] (A) -| (p1);
#
# \node[above left] at (1,2) {$u$};\node[above right] at (4,2) {$\dot x$};
# \node[above] at (6,2) {$x$};\node[above left] at (9.5,2) {$y$};
#
# %\draw[thick] (0,2) -- (0.5,2); \draw[fleche] (0.5,2) |- (K1);\draw[fleche] (0.5,2) |- (K3);
# %\draw[fleche] (K1) -| (p1);\draw[fleche] (K3) -| (p1);
# %\draw[thick] (p1) -- (5,2); \draw[fleche] (5,2) |- (K2);\draw[fleche] (5,2) |- (K4);
# %\draw[fleche] (K2) -| (p2);\draw[fleche] (K4) -| (p2);\draw[fleche] (p2) -- (10,2);
#
# %\node[above right] at (3,3) {$x_1$};\node[above right] at (7.5,3) {$x_2$};
# %\node[below right] at (3,1) {$x_3$};\node[below right] at (7.5,1) {$x_4$};
# %\node[above] at (0,2) {$u$};\node[above left] at (10,2) {$y$};

# %%
# %%tikz --scale .8 -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save Chgt-Base-ex12.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt]
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (8,8);
# %\foreach \x in {1,2,...,8} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,8} \draw(0,\y)node[below]{\y};
#
# \node[bloc,minimum height=1cm] (K4) at (2,6) {$\dfrac{1}{p+2}$};
# \node[bloc,minimum width=1.1cm] (K3) at (2,4.5) {$\dfrac{-2}{p}$};
# \node[bloc,minimum height=1cm] (K2) at (2,3) {$\dfrac{3/2}{p-1}$};
# \node[bloc,minimum height=1cm] (K1) at (2,1.5) {$\dfrac{-2}{p+1}$};
# \node[comp] (p1) at (4.5,1.5) {$3/4$};\node[comp] (p2) at (6,3) {};
# \draw[thick] (0,3) -- (0.5,3);
# \draw[fleche] (0.5,3) |- (K2);\draw[fleche] (0.5,3) |- (K3);\draw[fleche] (0.5,3) |- (K1);
# \draw[fleche] (K4) -| (p2);\draw[fleche] (p1) -| (p2);\draw[fleche] (K2) -- (p2);
# \draw[fleche] (K1) -- (p1);\draw[fleche] (K3) -- (4.5,4.5);\draw[fleche] (p2) -- (7.5,3);
#
# \node[above] at (0,3) {$u$};\node[above] at (3.5,1.5) {$\zeta_4$};
# \node[above] at (3.5,3) {$\zeta_3$};\node[above] at (3.5,4.5) {$\zeta_2$};
# \node[above] at (3.5,6) {$\zeta_1$};\node[above] at (7,3) {$y$};
# \node[left] at (6,2.5) {$+$};\node[above] at (5.5,3) {$+$};\node[right] at (6,3.5) {$-$};

# %%
# %%tikz --scale .8  -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save Modal-simple.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt]
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (8,8);
# %\foreach \x in {1,2,...,8} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,8} \draw(0,\y)node[below]{\y};
#
# \node[bloc,minimum height=1cm] (K3) at (2,5.5) {$\dfrac{1}{p-\lambda_n}$};
# \node[bloc,minimum height=1cm] (K2) at (2,3) {$\dfrac{1}{p-\lambda_2}$};
# \node[bloc,minimum height=1cm] (K1) at (2,1) {$\dfrac{1}{p-\lambda_1}$};
# \node[comp] (p1) at (4,1) {$\alpha_1$};
# \node[comp] (p2) at (4,3) {$\alpha_2$};
# \node[comp] (p3) at (4,5.5) {$\alpha_n$};\node[comp] (p4) at (6,3) {$+$};
# \draw[fleche] (K1) -- (p1);\draw[fleche] (K2) -- (p2);\draw[fleche] (K3) -- (p3);
# \draw[fleche] (p1) -| (p4);\draw[fleche] (p2) -- (p4);\draw[fleche] (p3) -| (p4);
# \draw[fleche] (p4) -- (7.5,3);
# \draw[thick] (0,3) -- (0.5,3);
# \draw[fleche] (0.5,3) |- (K2);\draw[fleche] (0.5,3) |- (K3);\draw[fleche] (0.5,3) |- (K1);
# \draw[thick, dashed] (2,4) -- (2,4.7);
#
# \node[above] at (0,3) {$u$};\node[above] at (7,3) {$y$};

# %%
# %%tikz --scale .8  -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save Modal-mult.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt]
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (8,6);
# %\foreach \x in {1,2,...,8} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,6} \draw(0,\y)node[below]{\y};
#
# \node[bloc,minimum height=1cm] (K3) at (2,5.5) {$\dfrac{1}{p-\gamma}$};
# \node[bloc,minimum height=1cm] (K2) at (2,3) {$\dfrac{1}{p-\gamma}$};
# \node[bloc,minimum height=1cm] (K1) at (2,1) {$\dfrac{1}{p-\gamma}$};
# \node[comp] (p1) at (5,1) {$\beta_1$};
# \node[comp] (p2) at (5,3) {$\beta_2$};
# \node[comp] (p3) at (5,5.5) {$\beta_r$};\node[comp] (p4) at (7,3) {$+$};
#
# \draw[fleche] (K1) -- (p1);\draw[fleche] (K2) -- (p2);\draw[fleche] (K3) -- (p3);
# \draw[fleche] (p1) -| (p4);\draw[fleche] (p2) -- (p4);\draw[fleche] (p3) -| (p4);
# \draw[fleche] (p4) -- (8.5,3);
#
# \draw[thick] (3.2,1) |- (0.5,2);\draw[fleche] (0.5,2) |- (K2);
# \draw[thick] (3.2,3) |- (2.5,4);\draw[thick, dashed] (2.5,4) -- (0.5,4);\draw[thick] (0.5,4) |- (K3);
# \draw[thick] (0,1) -- (K1);
#
# \node[above] at (0,1) {$u$};\node[above] at (8,3) {$y$};\node[above] at (3.8,5.5) {$\zeta_1$};
# \node[above] at (3.8,1) {$\zeta_r$};\node[above] at (3.8,3) {$\zeta_{r-1}$};

# %%
# %%tikz --scale .8 -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save Commandabilite.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt]
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (6,6);
# %\foreach \x in {1,2,...,6} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,6} \draw(0,\y)node[below]{\y};
#
# \draw[fleche] (3,0) -- (3,6);\draw[fleche] (0,3) -- (6,3);
# \draw[very thick] (.5,.5) -- (5.5,5.5);
# \draw[fleche] (5,3.5) -- (3.5,3.5);
#
# \node at (1,4){$\mathcal{X}=\mathbb{R}^2$};
# \node at (1,4.5){Espace d etat};
# \node[right] at (5,3.5){$x_2=x_1$};
# \node[right] at (5,4){Espace atteignable};
# \node[right] at (3,6){$x_2$};
# \node[below] at (6,3){$x_1$};

# %%
# %%tikz --scale .8  -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save Decompo-Comm.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt]
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (10,4);
# %\foreach \x in {1,2,...,10} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,4} \draw(0,\y)node[below]{\y};
#
# \node[right, bloc] (G2)at (.5,1) {$\dot \zeta_2=\bar A_{22} \zeta_2$};
# \node[right, bloc] (G1) at (1,3) {$\dot \zeta_1=\bar A_{11} \zeta_1+\bar A_{12} \zeta_2+\bar B_{1}u$};
# \node[right, bloc] (C1) at (7.5,3) {$\bar C_1$};\node[right, bloc] (C2) at (7.5,1) {$\bar C_2$};
# \node[comp] (p) at (9,2) {$+$};
#
# \draw[fleche] (0,3) -- (G1); \draw[fleche] (G1) -- (C1); \draw[fleche] (C1) -| (p);
# \draw[fleche] (G2) -- (C2); \draw[fleche] (C2) -| (p); \draw[fleche] (4,1) -| (G1);
# \draw[fleche] (p) -- (10,2);
# \node[above] at (0,3) {$u$};\node[above] at (4,1) {$\zeta_2$};\node[above] at (6.75,3) {$\zeta_1$};
# \node[above] at (10,2) {$y$};

# %%
# %%tikz --scale .8  -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save Decompo-Obs.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt]
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (10,4);
# %\foreach \x in {1,2,...,10} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,4} \draw(0,\y)node[below]{\y};
#
# \node[right, bloc] (G2)at (1.5,1) {$\dot \zeta_2=\bar A_{21} \zeta_1+\bar A_{22} \zeta_2+\bar B_{2} u$};
# \node[right, bloc] (G1) at (1.5,3) {$\dot \zeta_1=\bar A_{11} \zeta_1+\bar B_{1} u$};
# \node[right, bloc] (C1) at (7,3) {$\bar C_1$};
#
# \draw[fleche] (0,3) -- (G1); \draw[fleche] (G1) -- (C1); \draw[fleche] (C1) --(9,3);
# \draw[fleche] (1,3) |- (G2);\draw[fleche] (6,3) -- (6,1.4);
# \node[above right] at (0,3) {$u$};\node[above] at (6,3) {$\zeta_1$};%\node[above] at (6.5,3) {$\zeta_1$};
# \node[above left] at (9,3) {$y$};

# %%
# %%tikz --scale .8  -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save Place-poles.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,very thick,rounded corners=0pt]
#
#
# \usetikzlibrary{shapes,positioning,decorations.pathmorphing}
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (10,4);
# %\foreach \x in {1,2,...,10} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,4} \draw(0,\y)node[below]{\y};
#
# \node[cloud, draw, thick,align=left, cloud puffs=10,cloud puff arc=60, aspect=2, inner sep=0mm]
#     (S) at (6.5,3) {$\dot x=Ax+Bu$\\$y=Cx$};
# \node[bloc, minimum width=.8cm, minimum height=.8cm] (F) at (1.5,3) {$f$};
# \node[bloc, minimum width=.8cm,, minimum height=.8cm ] (K) at (4,1) {$-k$};
# \node[comp] (p) at (3,3) {$$};
#
# \draw[fleche] (0,3) -- (F);   \draw[fleche] (F) -- (p);  \draw[fleche] (p) -- (S);
# \draw[fleche] (K) -| (p);   \draw[fleche] (S) |- (K);     \draw[fleche] (S) -- (9.5,3);
# \node[above right] at (0,3) {$v$};\node[above left] at (9.5,3) {$y$};
# \node[above right] at (3.5,3) {$u$};
# \node[right] at (6.5,1.5) {$x$ (supposé ici accessible)};

# %%
# %%tikz --scale .8  -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save Observateur.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,very thick,rounded corners=0pt]
#
# \usetikzlibrary{shapes,positioning,decorations.pathmorphing}
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (10,6);
# %\foreach \x in {1,2,...,10} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,6} \draw(0,\y)node[below]{\y};
#
# \node[cloud, draw, thick,align=left, cloud puffs=10,cloud puff arc=60, aspect=2, inner sep=0mm]
#     (S) at (6.5,4) {$\dot x=Ax+Bu$\\$y=Cx$};
# \node[bloc, minimum width=.8cm, minimum height=.8cm] (Ob) at (6.5,2) {Observateur};
# \draw[fleche] (3,4) -- (S); \draw[fleche] (S) -- (10,4);
# \draw[fleche] (9,4) |- (Ob); \draw[fleche] (4,4) |- (Ob); \draw[fleche] (Ob) |- (3,1);
#
# \node[above right] at (3,4) {$u$};\node[above left] at (10,4) {$y$};
# \node[above ] at (3,1.1) {$\hat x$};
#
# %\node[bloc, minimum width=.8cm, minimum height=.8cm] (F) at (1.5,3) {$f$};
# %\node[bloc, minimum width=.8cm,, minimum height=.8cm ] (K) at (4,1) {$-k$};
# %\node[comp] (p) at (3,3) {$$};
#
# %\draw[fleche] (0,3) -- (F);   \draw[fleche] (F) -- (p);  \draw[fleche] (p) -- (S);
# %\draw[fleche] (K) -| (p);   \draw[fleche] (S) |- (K);     \draw[fleche] (S) -- (9.5,3);
# %\node[above right] at (0,3) {$v$};\node[above left] at (9.5,3) {$y$};
# %\node[above right] at (3.5,3) {$u$};
# %\node[right] at (6.5,1.5) {$x$ (supposé ici accessible)};

# %%
# %%tikz --scale .8  -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save Com-avec-Obs.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt,minimum width=.8cm, minimum height=.8cm]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,very thick,rounded corners=0pt]
#
# \usetikzlibrary{shapes,positioning,decorations.pathmorphing}
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (10,6);
# %\foreach \x in {1,2,...,10} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,6} \draw(0,\y)node[below]{\y};
#
# \node[cloud, draw, thick,align=left, cloud puffs=10,cloud puff arc=60, aspect=2, inner sep=0mm]
#     (S) at (7,4) {$\dot x=Ax+Bu$\\$y=Cx$};
# \node[bloc] (Ob) at (6.5,2) {Observateur};
# \node[bloc] (K) at (3,1) {$-k$};\node[bloc] (F) at (1.5,4) {$f$};
# \node[comp] (p) at (3,4) {$$};
#
# \draw[fleche] (0,4) -- (F);   \draw[fleche] (F) -- (p);
# \draw[fleche] (p) -- (S); \draw[fleche] (S) -- (10,4);
# \draw[fleche] (9.25,4) |- (Ob); \draw[fleche] (3.5,4) |- (Ob); \draw[fleche] (Ob) |- (K);
# \draw[fleche] (K) -- (p);
#
# \node[above] at (4.75,4) {$u$};\node[above left] at (10,4) {$y$};
# \node[above ] at (4.5,1.1) {$\hat x$}; \node[above ] at (0,4) {$v$};
#
# \draw[fill=lightgray,opacity=0.2,dashed,thick] (0.5,5) -- (4.25,5)
#   --(4.25,2.75)--(9.5,2.75)--(9.5,0)--(.5,0)--(0.5,5);
# \node[above ] at (8,0) {Regulateur};

# %%
# %%tikz --scale .8  -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save Obs-et-ObsRed.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt,minimum width=.8cm, minimum height=.8cm]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,very thick,rounded corners=0pt]
#
# \usetikzlibrary{shapes,positioning,decorations.pathmorphing}
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (15,4);
# %\foreach \x in {1,2,...,15} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,4} \draw(0,\y)node[below]{\y};
#
# \node[bloc] (Ob1) at (4,2) {$\dot{\hat{x}}=A\,\hat{x}+B\,u+L\,(y-C\,\hat{x}),$};
# \node[bloc] (Ob2) at (12,2) {$\begin{array}{c}\dot z=M\,z+N\,u+P\,y\\\hat{x}=F\,z+G\,y \end{array}$};
#
# \draw[fleche] (0.5,3) |- (Ob1); \draw[fleche] (7.5,3) |- (Ob1);\draw[fleche] (Ob1) |- (2,0.5);
# \draw[fleche] (9,3) |- (Ob2); \draw[fleche] (15,3) |- (Ob2);\draw[fleche] (Ob2) |- (10.5,0.5);
#
# \node[above] at (.5,3) {$u$};\node[above] at (7.5,3) {$y$};\node[above left] at (2,0.5) {$\hat x$};
# \node[above] at (9,3) {$u$};\node[above] at (15,3) {$y$};\node[above left] at (10.5,0.5) {$\hat x$};
# \node[above] at (7,-0.5) {Observateur complet et d'ordre réduit};
#
# %\node[bloc] (K) at (3,1) {$-k$};\node[bloc] (F) at (1.5,4) {$f$};
# %\node[comp] (p) at (3,4) {$$};
#
# %\draw[fleche] (0,4) -- (F);   \draw[fleche] (F) -- (p);
# %\draw[fleche] (p) -- (S); \draw[fleche] (S) -- (10,4);
# %\draw[fleche] (9.25,4) |- (Ob); \draw[fleche] (3.5,4) |- (Ob); \draw[fleche] (Ob) |- (K);
# %\draw[fleche] (K) -- (p);
#
# %\node[above] at (4.75,4) {$u$};\node[above left] at (10,4) {$y$};
# %\node[above ] at (4.5,1.1) {$\hat x$}; \node[above ] at (0,4) {$v$};
