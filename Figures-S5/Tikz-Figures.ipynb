# %%
# %load_ext tikzmagic

# %%
# %%tikz --scale .8 --size 600,200 -p amsmath amssymb -f svg --save RepFonct.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt];
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt];
# %\draw[line width=.2pt](0,0) grid (8,3);
#
# \node[bloc,minimum height=1cm] (G) at (4,1) {Systeme};
# \draw[fleche] (1,1) -- (G); \draw[fleche] (G) -- (7,1);\draw[fleche] (4,3) -- (G);
# \draw (1,1) node[above right] {$u(t)$};\draw (4,3) node[right] {$d(t)$};\draw (7,1) node[above left] {$y(t)$};
# \draw (1.5,.8) node[below, fill=cyan] {commandes};
# \draw (5,3) node[right, fill=cyan] {perturbations};
# \draw (6.5,.8) node[below, fill=cyan] {sorties};

# %%
# %%tikz --scale .8 --size 600,200 -p amsmath amssymb -f svg --save StructBouclee.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt,minimum height=.8cm];
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt];
# %\draw[line width=.2pt](0,0) grid (13,3.5);
#
# \node[bloc] (K) at (4,2) {calculateur};
# \node[bloc] (G) at (10,2) {Systeme};
# \node[bloc] (H) at (7,1) {capteur};
# \draw[fleche] (1,2) -- (K); \draw[fleche] (K) -- (G);\draw[fleche] (G) -- (13,2);
# \draw[fleche] (12,2) |- (H);\draw[fleche] (H) -| (K);\draw[fleche] (10,3.5) -- (G);
#
# \draw (1,2) node[above] {reference};\draw (7,2) node[above] {commande};
# \draw (13,2) node[above left] {sortie};\draw (10,3.5) node[above right] {perturbation};
# %\draw (6.5,.8) node[below, fill=green] {sorties};

# %%
# %%tikz --scale .8 --size 600,200 -p amsmath amssymb -f svg --save RealMaterielle.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt,minimum height=.8cm];
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt];
# %\draw[line width=.2pt](0,-1) grid (13,3.5);
#
# \node (K) at (4,2) {\includegraphics[height=2cm]{PhotoDspace.png}};
# \node[bloc] (G) at (10,2) {Systeme};
# \node[bloc] (H) at (7,1) {capteur};
# \draw[fleche] (1,2) -- (K); \draw[fleche] (K) -- (G);\draw[fleche] (G) -- (13,2);
# \draw[fleche] (12,2) |- (H);\draw[fleche] (H) -- (5,1);\draw[fleche] (10,3.5) -- (G);
#
# \node (PC) at (3.5,-.5) {\includegraphics[height=1cm]{PhotoPC.jpg}};
# \node (K) at (4,.5) {$\Updownarrow$};
#
# \draw (1,2) node[above] {reference};\draw (7,2) node[above] {commande};
# \draw (13,2.5) node[above left] {$y(t)$};\draw (10,3.2) node[right] {$d(t)$};
# \draw (5.5,.5) node{$c(t)$};
#
# \draw (1,2.5) node[above] {$r(t)$};\draw (7,2.5) node[above] {$u(t)$};
# \draw (13,2) node[above left] {sortie};\draw (10,3.5) node[above right] {perturbation};
#
# %\draw (6.5,.8) node[below, fill=green] {sorties};

# %%
# %%tikz --scale .8 --size 600,200 -p amsmath amssymb -f svg --save RegulVitesse.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt];
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt];
# %\draw[line width=.2pt](0,0) grid (15,3);
#
# \begin{scope} [scale =1.5,xshift=0cm,yshift=-1cm,rotate=20]%
# \node (Car) at (3,1.5) {\includegraphics[width=2cm,angle=20]{car.png}};
# \draw[fleche,rotate=0] (4,1.5) -- (5,1.5);
# \draw[fleche,rotate=0] (2,1.5) -- (1,1.5);
# \draw[fleche,rotate around={-20:(3,1.5)}] (3,1) -- (3,0.5);
# \draw[rotate=0] (1,1.15) -- (5,1.15);
# \draw[rotate around={-20:(1,1.15)}] (1,1.15) -- (5,1.15);
# \draw (2,1.15) arc (0:-20:1) ;
# \draw (1.2,1.85) node{$F_a$};
# \draw (4.5,1.75) node{$F_u$};
# \draw (3,.5) node{$mg$};
# \draw (2.15,.95) node{$\theta$};
#
# \end{scope}
#
# \begin{scope} [xshift=8cm]%
# \node[bloc,minimum height=1cm] (G) at (4,1) {Systeme};
# \draw[fleche] (1,1) -- (G); \draw[fleche] (G) -- (7,1);\draw[fleche] (4,3) -- (G);
# \draw (1,1) node[above right] {$u(t)$};\draw (4,3) node[right] {$\theta(t)$};\draw (7,1) node[above left] {$v(t)$};
# %\draw (1.5,.8) node[below, fill=green] {commandes};
# %\draw (5,3) node[right, fill=green] {perturbations};
# %\draw (6.5,.8) node[below, fill=green] {sorties};
# \end{scope}

# %%
# %%tikz --scale .8 --size 600,200 -p amsmath amssymb pgfplots -f svg --save MagLevFig.svg
# \usetikzlibrary{snakes}
# \usetikzlibrary{decorations.markings}
#
# \tikzset{->-/.style={decoration={
#   markings,
#   mark=at position .5 with {\arrow{>}}},postaction={decorate}}}
#
# %\draw[line width=.2pt](-.5,0) grid (4,3.5);
# \tikzstyle{bloc}=[draw,rectangle,rounded corners=1pt];
# \tikzstyle{fleche}=[->,>=stealth,rounded corners=0pt];
# \tikzstyle{fleche2}=[<->,>=stealth,rounded corners=0pt];
#
# \coordinate (a)  at (2,3);  \coordinate (b)  at (2,2);
# \draw[->-] (0,3) to (a);
#
# \draw[snake=coil,segment amplitude=6pt, segment length=2pt]  (a) -- (b);
# %\draw[rotate=0] (0,3) -- (a);
# \draw[rotate=0] (1,2) -- (b);
# \node[bloc,minimum height=.8cm] (R) at (1,1) {R};
# \draw[rotate=0] (1,2) -- (R);\draw[rotate=0] (R) |- (0,0);
# \shade [ball color=white] (2,.9) circle [radius=.4cm];
# \draw[fleche2,rotate=0] (b)+(.5,0) -- (2.5,1.25);
# \draw[fleche] (0,0.2) -- (0,2.8);
# \draw (-.5,1.5) node{$V$};\draw (1,3.3) node{$i$};\draw (2.7,1.65) node{$x$};
# \draw (1.32,2.5) node{$L$};

# %%
# %%tikz --scale .8 --size 600,200 -p amsmath amssymb pgfplots -f svg --save CarSteering.svg
#
# %\draw[line width=.2pt](-.5,0) grid (4,3.5);
# \tikzstyle{bloc}=[draw,rectangle,rounded corners=0pt];
# \tikzstyle{fleche}=[->,>=stealth,rounded corners=0pt];
# \tikzstyle{fleche2}=[<->,>=stealth,rounded corners=0pt];
#
# %\draw[line width=.2pt](0,-3) grid (10,3);
#
# \newcommand\centerofmass{%
#     \tikz[radius=0.4em] {%
#         \fill (0,0) -- ++(0.4em,0) arc [start angle=0,end angle=90] -- ++(0,-0.8em) arc [start angle=270, end angle=180];%
#         \draw (0,0) circle;%
#     }%
# }
#
# \newcommand\totale{
# \begin{scope}[rotate around={0:(2,0)}]
# \node[rotate around={0:(8,0)}] (rect) at (8,0) [draw,thick,minimum width=4cm,minimum height=2cm] {};
# \node[fill=black,rotate=0] (rect) at (6.5,0.65) [draw,thick,minimum width=1cm,minimum height=.25cm] {};
# \node[fill=black,rotate=0] (rect) at (6.5,-.65) [draw,thick,minimum width=1cm,minimum height=.25cm] {};
# \node[fill=black,rotate=-30] (rect) at (9.75,0.65) [draw,thick,minimum width=1cm,minimum height=.25cm] {};
# \node[fill=black,rotate=-30] (rect) at (9.75,-.65) [draw,thick,minimum width=1cm,minimum height=.25cm] {};
# \draw[fleche2] (6.5,1.75) -- (9.75,1.75);\draw (8,2) node{$L$};
# \draw[rotate around={-30:(9.5,0)}] (9.5,0) -- (12.5,0);
# \draw[rotate around={-0:(9.5,0)}] (2,0) -- (12.5,0);
# \draw[fleche,rotate around={-15:(2,0)}] (2,0) -- (5,0);
# \draw[fleche,rotate around={75:(2,0)}] (2,0) -- (5,0);
# \node (cdm) at (6.5,0) {\centerofmass};
# \draw[->] (4,0) arc (0:-15:2);
# \draw[->, very thick, blue] (11.5,0) arc (0:-30:2);
# \draw (4.5,-.3) node[rotate =-15]{$\theta$};%\draw (4.5,-1.3) node[rotate =-15]{$X$};
# \draw (12,-.65) node[rotate =-15]{$u_\phi$};
# \draw[fleche, very thick, blue] (6.5,0) -- (8.5,0);\draw (8.5,0.5) node[rotate =-15]{$u_v$};
# \draw[fleche] (4.5,0.5) -- (6.25,0.1);\draw (4.5,0.85) node[rotate =-15]{($x,y$)};
# \end{scope}
# }
# \begin{scope}
# \totale;
# \end{scope}

# %%
# %%tikz --scale .8 --size 600,200 -p amsmath amssymb pgfplots -f svg --save CarSteering2.svg
#
# %\draw[line width=.2pt](-.5,0) grid (4,3.5);
# \tikzstyle{bloc}=[draw,rectangle,rounded corners=0pt];
# \tikzstyle{fleche}=[->,>=stealth,rounded corners=0pt];
# \tikzstyle{fleche2}=[<->,>=stealth,rounded corners=0pt];
#
# %\draw[line width=.2pt](0,-3) grid (10,3);
#
# \newcommand\centerofmass{%
#     \tikz[radius=0.4em] {%
#         \fill (0,0) -- ++(0.4em,0) arc [start angle=0,end angle=90] -- ++(0,-0.8em) arc [start angle=270, end angle=180];%
#         \draw (0,0) circle;%
#     }%
# }
#
# \newcommand\totale{
# \begin{scope}[rotate around={15:(2,0)}]
# \node[rotate around={15:(0,0)}] (rect) at (8,0) [draw,thick,minimum width=4cm,minimum height=2cm] {};
# \node[fill=black,rotate=15] (rect) at (6.5,0.65) [draw,thick,minimum width=1cm,minimum height=.25cm] {};
# \node[fill=black,rotate=15] (rect) at (6.5,-.65) [draw,thick,minimum width=1cm,minimum height=.25cm] {};
# \node[fill=black,rotate=-20] (rect) at (9.75,0.65) [draw,thick,minimum width=1cm,minimum height=.25cm] {};
# \node[fill=black,rotate=-20] (rect) at (9.75,-.65) [draw,thick,minimum width=1cm,minimum height=.25cm] {};
# \draw[fleche2] (6.5,1.75) -- (9.75,1.75);\draw (8,2) node{$L$};
# \draw[rotate around={-30:(9.5,0)}] (9.5,0) -- (12.5,0);
# \draw[rotate around={-0:(9.5,0)}] (2,0) -- (12.5,0);
# \draw[fleche,rotate around={-15:(2,0)}] (2,0) -- (5,0);
# \draw[fleche,rotate around={75:(2,0)}] (2,0) -- (5,0);
# \node (cdm) at (7.5,0) {\centerofmass};
# \draw[->] (4,0) arc (0:-15:2);
# \draw[->, very thick, blue] (11.5,0) arc (0:-30:2);
# \draw (4.5,-.3) node[rotate =0]{$\theta$};%\draw (4.5,-1.3) node[rotate =-15]{$X$};
# \draw (12,-.65) node[rotate =0]{$\phi$};
# \draw[fleche, very thick, blue] (7.5,0) -- (9,0);\draw (8.5,0.3) node[rotate =0]{$v$};
# \draw[fleche] (4.5,0.5) -- (7.25,0.1);\draw (4.5,0.85) node[rotate =0]{($x,y$)};
# \end{scope}
# }
# \begin{scope}
# \totale;
# \end{scope}

# %%
# %%tikz --scale .8 --size 600,200 -p amsmath amssymb -f svg --save Terre-lune-vf.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt];
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt];
# %\draw[line width=.2pt](0,0) grid (10,6);
#
# %\begin{scope} [scale =1.5,xshift=0cm,yshift=-1cm,rotate=20]%
# \node (Sat) at (5,3) {\includegraphics[width=7cm,angle=0]{terre.pdf}};
# \draw (5.5,5.5) node{$\Omega$};
# \draw (9,2.5) node{$\theta$};
# \draw (8,4) node{$r$};
# %\end{scope}

# %%
# %%tikz --scale .8 --size 300,100 -p amsmath amssymb -f svg --save YegalHU.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt];
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt];
# %\draw[line width=.2pt](0,0) grid (4,2);
#
# \node[bloc,minimum height=1cm] (G) at (2,1) {$H(p)$};
# \draw[fleche] (0,1) -- (G); \draw[fleche] (G) -- (4,1);
# \draw (0,1) node[above right] {$U(p)$};\draw (4,1) node[above left] {$Y(p)$};
# %\draw (5,3) node[right, fill=green] {perturbations};
# %\draw (6.5,.8) node[below, fill=green] {sorties};

# %%
# %%tikz --scale .8 --size 600,200 -p amsmath amssymb -f svg --save RepOrdre1.svg
# \begin{scope}
# %\draw [gray, very thin] (0,0) grid [step=1cm] (8,3);
# %\foreach \x in {1,2,...,8} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,3} \draw(0,\y)node[below]{\y};
# \draw [line width=.3mm,->] (-.25,0) -- (6.5,0);
# \draw [line width=.3mm,->] (0,0) -- (0,3);
# %\draw [line width=.4mm,cyan](-.2,0) -- (0,0)-- (0,.5)-- (8,.5);
#
# \draw [domain=0:6,samples=80,line width=.4mm,blue] plot(\x,{2*(1-exp(-2*\x))});
# \draw [domain=0:6,samples=80,line width=.4mm,cyan] plot(\x,{2.5});
# \draw (6.5,0) node[above] {{$t$}};\draw (6.5,2.5) node [right]{{$u$}};\draw (6.5,2) node [right]{{$y$}};
# \draw [domain=0:6,samples=80,thin,gray] plot(\x,{2});\draw (0,2) node [left]{{$ku_0$}};
# \draw (0,2.5) node [left]{{$u_0$}};
# %\draw (4,2) -| (5,2.5);\draw (5,2.25) node[right] {\small{ $u_0$}};
# %\draw (4,1) -| (5,1.25);\draw (5,1.25) node[right] {\small{$ku_0$}};
# %\draw (3,-.50) node[below] {Réponse d'un $1^{er}$ ordre à une rampe $u=u_0\,t$};
# \end{scope}
#
#
# \begin{scope}[xshift= 9cm]
# \draw [line width=.3mm,->] (-.25,0) -- (8,0);
# \draw [line width=.3mm,->] (0,0) -- (0,3);
# %\draw [line width=.4mm,cyan](-.2,0) -- (0,0)-- (0,.5)-- (8,.5);
#
# \draw [domain=0:6,samples=80,line width=.4mm,blue] plot(\x,{0.3*0.5*exp(-2*\x)+0.3*(\x-0.5)});
# %\draw [domain=0:6,samples=80,line width=.4mm,blue] plot(\x,{0.5*0.5*exp(-2*\x)+0.5*(\x-0.5)});
# \draw [domain=0:6,samples=80,line width=.4mm,cyan] plot(\x,{0.5*(\x)});
# \draw (8,0) node[above] {{$t$}};\draw (3.5,2) node {{$u$}};\draw (3.5,.5) node {{$y$}};
# \draw (4,2) -| (5,2.5);\draw (5,2.25) node[right] {\small{pente $u_0$}};
# \draw (4,1) -| (5,1.25);\draw (5,1.25) node[right] {\small{pente $ku_0$}};
# %\draw (3,-.50) node[below] {Réponse d'un $1^{er}$ ordre à une rampe $u=u_0\,t$};
# \end{scope}

# %%
# %%tikz --scale .8 --size 600,200 -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save RepOrdre2.svg
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (12,3);
# %\foreach \x in {1,2,...,10} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,3} \draw(0,\y)node[below]{\y};
# \begin{scope}[xshift=-1cm]
# \begin{axis}[ymax=1.75,yscale=1.5, axis x line=none,axis y line = none, height=4cm,width=12cm]
# %\fill[gray!20] (axis cs:0.01,0.95) -- (axis cs:20,0.95) -- (axis cs:20,1.05) -- (axis cs:0.01,1.05) -- cycle;
# \draw [line width=.3mm,->] (axis cs:0,0) -- (axis cs:20,0);
# \draw [line width=.3mm,->] (axis cs:0,0) -- (axis cs:0,1.7);
# \draw [line width=.3mm,dashed] (axis cs:0,1) -- (axis cs:20,1);\draw (axis cs:0,1) node[left] {{$ku_0$}};
# \draw [line width=.3mm,<->] (axis cs:3.25,1) -- (axis cs:3.25,1.5);\draw (axis cs:3.5,1.55) node[right]
# {{$D=(y_{max}-y_\infty)/y_\infty$}};
# \draw [line width=.3mm,dashed] (axis cs:3.25,1) -- (axis cs:3.25,0);\draw (axis cs:3.15,.1) node[right] {{$t_p$}};
#
# \addplot[mark=none,draw=blue,very thick] file {RepIndice1.txt};
# \addplot[mark=none,draw=cyan,very thick] file {RepIndice2.txt};
# \end{axis}
#
# \end{scope}
# \begin{scope}
# \draw (12,2.5) node[left] {{$D=e^{\dfrac{-\pi\zeta}{\sqrt{1-\zeta^2}}}$}};
# \draw (12,1) node[left] {{$t_p=\dfrac{\pi}{\omega_n\sqrt{1-\zeta^2}}$}};
# %\draw (6,-1) node[above] {{Réponses indicielles oscillante ($\zeta<1$) et amortie ($\zeta\geq1$)}};
# \end{scope}
# %\draw (2,0) node[below] {{$\tau$}};

# %%
# %%tikz --scale .8 --size 600,200 -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save SB-KGH.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt]
# %\draw [gray, very thin] (0,0) grid [step=1cm] (10,4);
# %\foreach \x in {1,2,...,10} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,4} \draw(0,\y)node[below]{\y};
# \node[above right] at (1,3) {$x(t)$};\node[above left] at (10,3) {$y(t)$};
# \node[above] at (4,3) {$\varepsilon(t)$};\node[above] at (6.75,3) {$u(t)$};
# \node[comp] (p) at (3,3) {$\pm$};
# \node[bloc,minimum height=1cm] (K) at (5.5,3) {$K(p)$};
# \node[bloc,minimum height=1cm] (G) at (8,3) {$G(p)$};
# \node[bloc,minimum height=1cm] (H) at (5,1.5) {$H(p)$};
# \draw[fleche] (1,3) -- (p); \draw[fleche] (p) -- (K); \draw[fleche] (K) -- (G);\draw[fleche] (G) -- (10,3);
# \draw[fleche] (9,3) |- (H); \draw[fleche] (H) -| (p);

# %%
# %%tikz --scale .8 --size 600,200 -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save SB-KGH-D.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt]
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (10,4);
# %\foreach \x in {1,2,...,10} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,4} \draw(0,\y)node[below]{\y};
# \node[above right] at (.5,3) {$x(t)$};\node[above left] at (10,3) {$y(t)$};
# \node[comp] (p) at (2,3) {$\pm$};
# \node[bloc,minimum height=1cm] (K) at (4,3) {$K(p)$};
# \node[comp] (p2) at (6,3) {$+$};
# \node[bloc,minimum height=1cm] (G) at (8,3) {$G(p)$};
# \node[bloc,minimum height=1cm] (H) at (4,1.5) {$H(p)$};
# \draw[fleche] (.5,3) -- (p); \draw[fleche] (p) -- (K); \draw[fleche] (K) -- (p2);
# \draw[fleche] (p2) -- (G);\draw[fleche] (G) -- (10,3);
# \draw[fleche] (9,3) |- (H); \draw[fleche] (H) -| (p);\draw[fleche] (6,4) -| (p2);
# \node[right] at (6,4) {$d(t)$};

# %%
# %%tikz --scale .8 --size 600,200 -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save SB-Stab-Ex.svg
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt]
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (10,4);
# %\foreach \x in {1,2,...,10} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,4} \draw(0,\y)node[below]{\y};
# \node[above right] at (1,3) {$x(t)$};\node[above] at (10,3) {$y(t)$};
# \node[comp] (p) at (3,3) {$\pm$};
# \node[bloc,minimum height=1cm,minimum width=1cm] (K) at (5,3) {$k$};
# \node[bloc,minimum height=1cm] (G) at (8,3) {$\dfrac{1}{p(p+1)}$};
# \node[bloc,minimum height=1cm] (H) at (5,1.5) {$\dfrac{1}{(p+5)}$};
# \draw[fleche] (1,3) -- (p); \draw[fleche] (p) -- (K); \draw[fleche] (K) -- (G);\draw[fleche] (G) -- (10.5,3);
# \draw[fleche] (9.5,3) |- (H); \draw[fleche] (H) -| (p);

# %%
# %%tikz --scale .8 --size 600,200 -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save SB-KG1.svg
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt]
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (10,4);
# %\foreach \x in {1,2,...,10} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,4} \draw(0,\y)node[below]{\y};
# \node[above right] at (1,3) {$x(t)$};\node[above left] at (9,3) {$y(t)$};
# \node[above] at (3.8,3) {$\varepsilon(t)$};
# \node[comp] (p) at (3,3) {$\pm$};
# \node[bloc,minimum height=1cm] (K) at (5,3) {$K(p)$};
# \node[bloc,minimum height=1cm] (G) at (7,3) {$G(p)$};
# \draw[fleche] (1,3) -- (p); \draw[fleche] (p) -- (K); \draw[fleche] (K) -- (G);\draw[fleche] (G) -- (9,3);
# \draw[thick] (8,3) |- (4,2); \draw[fleche] (4,2) -| (p);

# %%
# %%tikz --scale .8 --size 600,200 -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save SB-precision.svg
#
# \def \ze {.3};\def \om {2};\def \omp {\om*sqrt(1-\ze^2)};
# \def \ph {(asin(\ze))};
# \draw [thin] (0,0) grid [xstep=6cm, ystep=2.5cm] (12,5);
# %\foreach \x in {1,2,...,10} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,3} \draw(0,\y)node[below]{\y};
# \begin{scope}[xshift=1cm, yshift=2.75cm,scale=.5,yscale=2]
# \draw [line width=.3mm,->] (-.25,0) -- (8,0);
# \draw [line width=.3mm,->] (0,0) -- (0,2);
# \draw [domain=0:7,samples=40,line width=.4mm,cyan] (0,0) -- (0,1.3)--(7,1.3);
# \draw [domain=0:7,samples=40,line width=.4mm,blue] plot(\x,{1-exp(-\ze*\om*\x)*sin((\omp*\x+\ph) r)/sin((\ph) r)});
# \end{scope}
# \begin{scope}[xshift=7cm, yshift=2.75cm,scale=.5,yscale=2]
# \draw [line width=.3mm,->] (-.25,0) -- (8,0);
# \draw [line width=.3mm,->] (0,0) -- (0,2);
# \draw [domain=0:7,samples=40,line width=.4mm,cyan] (0,0) -- (0,1.3)--(7,1.3);
# \draw [domain=0:7,samples=40,line width=.4mm,blue] plot(\x,{1.3*(1-exp(-\ze*\om*\x)*sin((\omp*\x+\ph) r)/sin((\ph) r))});
# \end{scope}
# %%
# %*
# \begin{scope}[xshift=1cm,  yshift=.5cm,scale=.5]
# \draw [line width=.3mm,->] (-.25,0) -- (8,0);
# \draw [line width=.3mm,->] (0,0) -- (0,3);
# \draw [domain=0:6,samples=80,line width=.4mm,blue] plot(\x,{0.2*0.5*exp(-2*\x)+0.2*(\x-0.5)});
# \draw [domain=0:6,samples=80,line width=.4mm,cyan] plot(\x,{0.5*(\x)});
# \draw (8,0) node[above] {{$t$}};\draw (3.5,2) node {{$u$}};\draw (3.5,.5) node {{$y$}};
# \end{scope}
# \begin{scope}[xshift=7cm, yshift=.5cm, scale=.5]
# \draw [line width=.3mm,->] (-.25,0) -- (8,0);
# \draw [line width=.3mm,->] (0,0) -- (0,3);
# %\draw [line width=.4mm,cyan](-.2,0) -- (0,0)-- (0,.5)-- (8,.5);
# \draw [domain=0:6,samples=80,line width=.4mm,blue] plot(\x,{0.5*0.5*exp(-2*\x)+0.5*(\x-0.5)});
# \draw [domain=0:6,samples=80,line width=.4mm,cyan] plot(\x,{0.5*(\x)});
# \draw (8,0) node[above] {{$t$}};\draw (3.5,2) node {{$u$}};\draw (3.5,.5) node {{$y$}};
# \end{scope}
# %\draw (3,-.50) node[below] {Titre};

# %%
# %%tikz --scale .8 --size 600,200 -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save SB-KG1-D.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt]
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (10,4);
# %\foreach \x in {1,2,...,10} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,4} \draw(0,\y)node[below]{\y};
# \node[above right] at (.5,3) {$x(t)$};\node[above left] at (10,3) {$y(t)$};
# \node[comp] (p) at (2,3) {$\pm$};
# \node[bloc,minimum height=1cm] (K) at (4,3) {$K(p)$};
# \node[comp] (p2) at (6,3) {$+$};
# \node[bloc,minimum height=1cm] (G) at (8,3) {$G(p)$};
# %\node[bloc,minimum height=1cm] (H) at (4,1.5) {$H(p)$};
# \draw[fleche] (.5,3) -- (p); \draw[fleche] (p) -- (K); \draw[fleche] (K) -- (p2);
# \draw[fleche] (p2) -- (G);\draw[fleche] (G) -- (10,3);
# %\draw[fleche] (9,3) |- (H); \draw[fleche] (H) -| (p);
# \draw[thick] (9,3) |- (4,1.5); \draw[fleche] (4,1.5) -| (p);
#
# \draw[fleche] (6,4) -| (p2);
# \node[right] at (6,4) {$d(t)$};

# %%
# %%tikz --scale .8 --size 600,200 -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg
# %--save SB-KG1-D2.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt]
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (10,4);
# %\foreach \x in {1,2,...,10} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,4} \draw(0,\y)node[below]{\y};
# \node[above right] at (.5,3) {$x(t)$};\node[above left] at (10,3) {$y(t)$};
# \node[comp] (p) at (2,3) {$\pm$};
# \node[bloc,minimum height=1cm] (K) at (4,3) {$K(p)$};
# \node[comp] (p2) at (8,3) {$+$};
# \node[bloc,minimum height=1cm] (G) at (6,3) {$G(p)$};
# %\node[bloc,minimum height=1cm] (H) at (4,1.5) {$H(p)$};
# \draw[fleche] (.5,3) -- (p); \draw[fleche] (p) -- (K); \draw[fleche] (K) -- (G);
# \draw[fleche] (G) -- (p2);\draw[fleche] (p2) -- (10,3);
# %\draw[fleche] (9,3) |- (H); \draw[fleche] (H) -| (p);
# \draw[thick] (9,3) |- (4,1.5); \draw[fleche] (4,1.5) -| (p);
#
# \draw[fleche] (8,4) -| (p2);
# \node[right] at (8,4) {$d(t)$};

# %%
# %%tikz --scale .8 --size 600,200 -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save SB-KG1-D3.svg
#
# \tikzstyle{bloc}=[draw,rectangle,thick,rounded corners=1pt]
# \tikzstyle{comp}=[circle,draw]
# \tikzstyle{fleche}=[->,>=stealth,thick,rounded corners=0pt]
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (10,4);
# %\foreach \x in {1,2,...,10} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,4} \draw(0,\y)node[below]{\y};
# \node[above right] at (.5,3) {$x(t)$};\node[above left] at (10,3) {$y(t)$};
# \node[comp] (p) at (2,3) {$\pm$};
# \node[bloc,minimum height=1cm] (K) at (4,3) {$K(p)$};
# \node[comp] (p2) at (6,3) {$+$};
# \node[comp] (p3) at (9,1.5) {$+$};
# \node[bloc,minimum height=1cm] (G) at (8,3) {$G(p)$};
# %\node[bloc,minimum height=1cm] (H) at (4,1.5) {$H(p)$};
# \draw[fleche] (.5,3) -- (p); \draw[fleche] (p) -- (K); \draw[fleche] (K) -- (p2);
# \draw[fleche] (p2) -- (G);\draw[fleche] (G) -- (10,3);
# %\draw[fleche] (9,3) |- (H); \draw[fleche] (H) -| (p);
# \draw[fleche] (6,4) -- (p2);
# \draw[fleche] (9,3) -- (p3); \draw[fleche] (10,1.5) -- (p3);\draw[fleche] (p3) -| (p);
#
# \node[right] at (10,1.5) {$\eta(t)$};
#
# \node[right] at (6,4) {$d(t)$};

# %%
# %%tikz --scale .8 --size 600,200 -p pgfplots,amsmath,amssymb -x \pgfplotsset{compat=1.16} -f svg --save SB-precision-Illustration.svg
#
# %\draw [gray, very thin] (0,0) grid [step=1cm] (12,3);
# %\foreach \x in {1,2,...,10} \draw(\x,0)node[left]{\x};
# %\foreach \y in {0,1,...,3} \draw(0,\y)node[below]{\y};
# \begin{scope}[xshift=0cm]
# \begin{axis}[xscale=1,yscale=1.5, axis x line=bottom,axis y line = left, height=4cm,width=8cm]
# \addplot[mark=none,draw=cyan,thick] file {RegThermP.txt};
# \addplot[mark=none,draw=blue,thick] file {RegThermPI.txt};
# \addplot[mark=none,draw=black,thick] file {RegThermInput.txt};
# \addplot[mark=none,draw=black,thick] file {RegThermPerturb.txt};
# %H=1/s+1 K=4 puis K=3 + 15/s
# %\draw (axis cs:1.5,.5) node[above] {\small{ajout d'un pôle/zéro}};
# %\draw (axis cs:1.5,.3) node[above] {\small{$z=5\,(\zeta\omega_n)$}};
# \end{axis}
# \end{scope}
